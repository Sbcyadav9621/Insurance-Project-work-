# %%
# DATA EXPLORATORY ANALYSIS AND HYPOTHESIS TESTING FOR  INSURANCE CLAIMS DATA

# %%
# importing liabraries
import numpy as np
import pandas as pd

from datetime import datetime as dt

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import scipy.stats as stats

# %% [raw]
# 1. Import claims_data.csv and cust_data.csv which is provided to you and
# combine the two datasets appropriately to create a 360-degree view of
# the data. Use the same for the subsequent questions.

# %%
claim = pd.read_csv("C://projects/python/Case Study 3 - Insurance Claims Case Study/claims.csv")

# %%
demogs = pd.read_csv("C://projects/python/Case Study 3 - Insurance Claims Case Study/cust_demographics.csv")

# %%
claim
# Out:
#       claim_id  customer_id      incident_cause  claim_date claim_area  \
# 0     54004764     21868593        Driver error  11/27/2017       Auto
# 1     33985796     75740424               Crime  10/03/2018       Home
# 2     53522022     30308357  Other driver error  02/02/2018       Auto
# 3     13015401     47830476      Natural causes  06/17/2018       Auto
# 4     22890252     19269962               Crime  01/13/2018       Auto
# ...        ...          ...                 ...         ...        ...
# 1095  97727122     35951012  Other driver error  06/11/2017       Auto
# 1096  10247193     14818669      Natural causes  03/14/2018       Auto
# 1097  79807493     85322831  Other driver error  02/09/2018       Auto
# 1098  69299345     73449366        Other causes  03/21/2018       Auto
# 1099  58809728     43020876  Other driver error  06/04/2017       Auto
#
#      police_report           claim_type claim_amount  total_policy_claims  \
# 0               No        Material only        $2980                  1.0
# 1          Unknown        Material only        $2980                  3.0
# 2               No        Material only      $3369.5                  1.0
# 3               No        Material only        $1680                  1.0
# 4               No        Material only        $2680                  1.0
# ...            ...                  ...          ...                  ...
# 1095            No        Material only        $3059                  4.0
# 1096            No        Material only        $1520                  2.0
# 1097            No  Material and injury       $23575                  2.0
# 1098       Unknown  Material and injury       $25120                  1.0
# 1099           Yes  Material and injury       $36685                  3.0
#
#      fraudulent
# 0            No
# 1            No
# 2           Yes
# 3            No
# 4            No
# ...         ...
# 1095        Yes
# 1096         No
# 1097        Yes
# 1098         No
# 1099        Yes
#
# [1100 rows x 10 columns]

# %%
demogs
# Out:
#        CUST_ID  gender DateOfBirth State       Contact   Segment
# 0     21868593  Female   12-Jan-79    VT  789-916-8172  Platinum
# 1     75740424  Female   13-Jan-70    ME  265-543-1264    Silver
# 2     30308357  Female   11-Mar-84    TN  798-631-4758    Silver
# 3     47830476  Female   01-May-86    MA  413-187-7945    Silver
# 4     19269962    Male   13-May-77    NV  956-871-8691      Gold
# ...        ...     ...         ...   ...           ...       ...
# 1080  79539873  Female   15-Mar-81    ND  459-425-4319  Platinum
# 1081  42364152  Female   07-Jul-96    ID  529-462-1635    Silver
# 1082  19888166    Male   11-Apr-90    WI  712-651-9613      Gold
# 1083  11256802  Female   22-Oct-64    LA  469-345-5617    Silver
# 1084  61575264    Male   12-Jul-95    WY  182-385-1392      Gold
#
# [1085 rows x 6 columns]

# %%
claim.head()
# Out:
#    claim_id  customer_id      incident_cause  claim_date claim_area  \
# 0  54004764     21868593        Driver error  11/27/2017       Auto
# 1  33985796     75740424               Crime  10/03/2018       Home
# 2  53522022     30308357  Other driver error  02/02/2018       Auto
# 3  13015401     47830476      Natural causes  06/17/2018       Auto
# 4  22890252     19269962               Crime  01/13/2018       Auto
#
#   police_report     claim_type claim_amount  total_policy_claims fraudulent
# 0            No  Material only        $2980                  1.0         No
# 1       Unknown  Material only        $2980                  3.0         No
# 2            No  Material only      $3369.5                  1.0        Yes
# 3            No  Material only        $1680                  1.0         No
# 4            No  Material only        $2680                  1.0         No

# %%
demogs.head()
# Out:
#     CUST_ID  gender DateOfBirth State       Contact   Segment
# 0  21868593  Female   12-Jan-79    VT  789-916-8172  Platinum
# 1  75740424  Female   13-Jan-70    ME  265-543-1264    Silver
# 2  30308357  Female   11-Mar-84    TN  798-631-4758    Silver
# 3  47830476  Female   01-May-86    MA  413-187-7945    Silver
# 4  19269962    Male   13-May-77    NV  956-871-8691      Gold

# %%
claims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   claim_id             1100 non-null   int64
#  1   customer_id          1100 non-null   int64
#  2   incident_cause       1100 non-null   object
#  3   claim_date           1100 non-null   object
#  4   claim_area           1100 non-null   object
#  5   police_report        1100 non-null   object
#  6   claim_type           1100 non-null   object
#  7   claim_amount         1035 non-null   object
#  8   total_policy_claims  1090 non-null   float64
#  9   fraudulent           1100 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 86.1+ KB

# %%
demogs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CUST_ID      1085 non-null   int64
#  1   gender       1085 non-null   object
#  2   DateOfBirth  1085 non-null   object
#  3   State        1085 non-null   object
#  4   Contact      1085 non-null   object
#  5   Segment      1085 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 51.0+ KB

# %%
complete = pd.merge(demogs,claim,
                    left_on = 'CUST_ID',
                    right_on = 'customer_id',
                    how = 'inner')

# %%
complete
# Out:
#        CUST_ID  gender DateOfBirth State       Contact   Segment  claim_id  \
# 0     21868593  Female   12-Jan-79    VT  789-916-8172  Platinum  54004764
# 1     75740424  Female   13-Jan-70    ME  265-543-1264    Silver  33985796
# 2     30308357  Female   11-Mar-84    TN  798-631-4758    Silver  53522022
# 3     30308357  Female   11-Mar-84    TN  798-631-4758    Silver  63017412
# 4     47830476  Female   01-May-86    MA  413-187-7945    Silver  13015401
# ...        ...     ...         ...   ...           ...       ...       ...
# 1080  79539873  Female   15-Mar-81    ND  459-425-4319  Platinum  62020796
# 1081  42364152  Female   07-Jul-96    ID  529-462-1635    Silver  63269067
# 1082  19888166    Male   11-Apr-90    WI  712-651-9613      Gold  22690595
# 1083  11256802  Female   22-Oct-64    LA  469-345-5617    Silver  12376894
# 1084  61575264    Male   12-Jul-95    WY  182-385-1392      Gold  63226031
#
#       customer_id      incident_cause  claim_date claim_area police_report  \
# 0        21868593        Driver error  11/27/2017       Auto            No
# 1        75740424               Crime  10/03/2018       Home       Unknown
# 2        30308357  Other driver error  02/02/2018       Auto            No
# 3        30308357        Driver error  04/04/2018       Auto            No
# 4        47830476      Natural causes  06/17/2018       Auto            No
# ...           ...                 ...         ...        ...           ...
# 1080     79539873  Other driver error  09/06/2018       Auto           Yes
# 1081     42364152        Other causes  05/09/2017       Home            No
# 1082     19888166  Other driver error  05/15/2017       Auto           Yes
# 1083     11256802  Other driver error  04/18/2017       Auto            No
# 1084     61575264      Natural causes  03/16/2017       Auto            No
#
#          claim_type claim_amount  total_policy_claims fraudulent
# 0     Material only        $2980                  1.0         No
# 1     Material only        $2980                  3.0         No
# 2     Material only      $3369.5                  1.0        Yes
# 3     Material only        $1950                  6.0         No
# 4     Material only        $1680                  1.0         No
# ...             ...          ...                  ...        ...
# 1080  Material only        $1770                  1.0         No
# 1081  Material only        $2800                  1.0         No
# 1082    Injury only       $33080                  2.0         No
# 1083  Material only        $2840                  4.0         No
# 1084  Material only        $1490                  1.0         No
#
# [1085 rows x 16 columns]

# %% [raw]
#  2. Perform a data audit for the datatypes and find out if there are any
# mismatch within the current datatypes of the columns and their
# business significance.

# %%
complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CUST_ID              1085 non-null   int64
#  1   gender               1085 non-null   object
#  2   DateOfBirth          1085 non-null   object
#  3   State                1085 non-null   object
#  4   Contact              1085 non-null   object
#  5   Segment              1085 non-null   object
#  6   claim_id             1085 non-null   int64
#  7   customer_id          1085 non-null   int64
#  8   incident_cause       1085 non-null   object
#  9   claim_date           1085 non-null   object
#  10  claim_area           1085 non-null   object
#  11  police_report        1085 non-null   object
#  12  claim_type           1085 non-null   object
#  13  claim_amount         1020 non-null   object
#  14  total_policy_claims  1075 non-null   float64
#  15  fraudulent           1085 non-null   object
# dtypes: float64(1), int64(3), object(12)
# memory usage: 135.8+ KB

# %%
# Mismatch data type treatments

# %%
complete.DateOfBirth = pd.to_datetime(complete.DateOfBirth,format = '%d-%b-%y')

# %%
complete.claim_date = pd.to_datetime(complete.claim_date,format = '%m/%d/%Y')

# %%
complete
# Out:
#        CUST_ID  gender DateOfBirth State       Contact   Segment  claim_id  \
# 0     21868593  Female  1979-01-12    VT  789-916-8172  Platinum  54004764
# 1     75740424  Female  1970-01-13    ME  265-543-1264    Silver  33985796
# 2     30308357  Female  1984-03-11    TN  798-631-4758    Silver  53522022
# 3     30308357  Female  1984-03-11    TN  798-631-4758    Silver  63017412
# 4     47830476  Female  1986-05-01    MA  413-187-7945    Silver  13015401
# ...        ...     ...         ...   ...           ...       ...       ...
# 1080  79539873  Female  1981-03-15    ND  459-425-4319  Platinum  62020796
# 1081  42364152  Female  1996-07-07    ID  529-462-1635    Silver  63269067
# 1082  19888166    Male  1990-04-11    WI  712-651-9613      Gold  22690595
# 1083  11256802  Female  2064-10-22    LA  469-345-5617    Silver  12376894
# 1084  61575264    Male  1995-07-12    WY  182-385-1392      Gold  63226031
#
#       customer_id      incident_cause claim_date claim_area police_report  \
# 0        21868593        Driver error 2017-11-27       Auto            No
# 1        75740424               Crime 2018-10-03       Home       Unknown
# 2        30308357  Other driver error 2018-02-02       Auto            No
# 3        30308357        Driver error 2018-04-04       Auto            No
# 4        47830476      Natural causes 2018-06-17       Auto            No
# ...           ...                 ...        ...        ...           ...
# 1080     79539873  Other driver error 2018-09-06       Auto           Yes
# 1081     42364152        Other causes 2017-05-09       Home            No
# 1082     19888166  Other driver error 2017-05-15       Auto           Yes
# 1083     11256802  Other driver error 2017-04-18       Auto            No
# 1084     61575264      Natural causes 2017-03-16       Auto            No
#
#          claim_type claim_amount  total_policy_claims fraudulent
# 0     Material only        $2980                  1.0         No
# 1     Material only        $2980                  3.0         No
# 2     Material only      $3369.5                  1.0        Yes
# 3     Material only        $1950                  6.0         No
# 4     Material only        $1680                  1.0         No
# ...             ...          ...                  ...        ...
# 1080  Material only        $1770                  1.0         No
# 1081  Material only        $2800                  1.0         No
# 1082    Injury only       $33080                  2.0         No
# 1083  Material only        $2840                  4.0         No
# 1084  Material only        $1490                  1.0         No
#
# [1085 rows x 16 columns]

# %%
# treatment on 'Contact' column

# %%
complete['Contact']
# Out:
# 0       789-916-8172
# 1       265-543-1264
# 2       798-631-4758
# 3       798-631-4758
# 4       413-187-7945
#             ...
# 1080    459-425-4319
# 1081    529-462-1635
# 1082    712-651-9613
# 1083    469-345-5617
# 1084    182-385-1392
# Name: Contact, Length: 1085, dtype: object

# %%
complete.Contact = complete.Contact.str.replace('-','')

# %%
complete.Contact
# Out:
# 0       7899168172
# 1       2655431264
# 2       7986314758
# 3       7986314758
# 4       4131877945
#            ...
# 1080    4594254319
# 1081    5294621635
# 1082    7126519613
# 1083    4693455617
# 1084    1823851392
# Name: Contact, Length: 1085, dtype: object

# %%
complete.Contact = complete.Contact.astype('Int64')

# %%
complete.Contact
# Out:
# 0       7899168172
# 1       2655431264
# 2       7986314758
# 3       7986314758
# 4       4131877945
#            ...
# 1080    4594254319
# 1081    5294621635
# 1082    7126519613
# 1083    4693455617
# 1084    1823851392
# Name: Contact, Length: 1085, dtype: Int64

# %% [raw]
#  3. Convert the column claim_amount to numeric. Use the appropriate
# modules/attributes to remove the $ sign.

# %%
complete['claim_amount'] = complete['claim_amount'].str.replace('$','')

# %%
complete['claim_amount'] = complete['claim_amount'].astype(float)

# %%
complete.claim_amount
# Out:
# 0        2980.0
# 1        2980.0
# 2        3369.5
# 3        1950.0
# 4        1680.0
#          ...
# 1080     1770.0
# 1081     2800.0
# 1082    33080.0
# 1083     2840.0
# 1084     1490.0
# Name: claim_amount, Length: 1085, dtype: float64

# %% [raw]
#  4. Of all the injury claims, some of them have gone unreported with the
# police. Create an alert flag (1,0) for all such claims.

# %%
complete['flag'] = np.where(complete.police_report.isin(['No','Unknown']),0,1)

# %%
complete.flag
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1080    1
# 1081    0
# 1082    1
# 1083    0
# 1084    0
# Name: flag, Length: 1085, dtype: int32

# %% [raw]
#  5. One customer can claim for insurance more than once and in each claim, multiple categories of claims can be involved. However, customer ID should remain unique.
# Retain the most recent observation and delete any duplicated records in the data based on the customer ID column.

# %%
complete = complete.sort_values('claim_date',ascending = False)

# %%
complete.reset_index(drop = True, inplace = True)

# %%
complete.drop_duplicates(subset = 'CUST_ID', inplace = True)

# %%
complete
# Out:
#        CUST_ID  gender DateOfBirth State     Contact   Segment  claim_id  \
# 0     93915431    Male  2067-09-08    ME  1347851687      Gold  99775483
# 1     38011078  Female  1976-05-20    NE  2711231475      Gold  98795403
# 2     58451506    Male  2068-04-22    FL  6735747823      Gold  43042986
# 3     46710738    Male  1977-04-28    MO  9628349361      Gold  74761374
# 4     77510822  Female  1986-03-18    AK  4369347156    Silver  87329176
# ...        ...     ...         ...   ...         ...       ...       ...
# 1080  77219712  Female  1999-08-05    NH  6495928793  Platinum  61374372
# 1081  42664554  Female  1993-08-13    TN  3969732531      Gold  42280334
# 1082  64840478  Female  1974-02-14    NM  9181747461    Silver  23636125
# 1083  74155265    Male  1985-11-16    TX  3927394873      Gold  25647821
# 1084  61745840  Female  1994-07-24    MA  6126845472  Platinum  90591192
#
#       customer_id      incident_cause claim_date claim_area police_report  \
# 0        93915431        Other causes 2018-10-30       Auto            No
# 1        38011078               Crime 2018-10-30       Auto       Unknown
# 2        58451506      Natural causes 2018-10-30       Auto            No
# 3        46710738        Driver error 2018-10-30       Auto            No
# 4        77510822  Other driver error 2018-10-30       Auto       Unknown
# ...           ...                 ...        ...        ...           ...
# 1080     77219712        Other causes 2017-01-01       Auto            No
# 1081     42664554        Other causes 2017-01-01       Auto            No
# 1082     64840478  Other driver error 2017-01-01       Auto       Unknown
# 1083     74155265      Natural causes 2017-01-01       Auto            No
# 1084     61745840  Other driver error 2017-01-01       Home            No
#
#                claim_type  claim_amount  total_policy_claims fraudulent  flag
# 0     Material and injury       42124.5                  1.0        Yes     0
# 1           Material only        1940.0                  1.0         No     0
# 2           Material only        2420.0                  1.0         No     0
# 3           Material only        1830.0                  1.0         No     0
# 4           Material only           NaN                  2.0         No     0
# ...                   ...           ...                  ...        ...   ...
# 1080  Material and injury       20200.0                  1.0         No     0
# 1081          Injury only       27670.0                  1.0         No     0
# 1082  Material and injury       17290.0                  1.0         No     0
# 1083        Material only        2080.0                  1.0         No     0
# 1084  Material and injury       30930.0                  1.0         No     0
#
# [1078 rows x 17 columns]

# %%
(complete['CUST_ID'].value_counts() > 1).sum()
# Out:
# 0

# %% [raw]
#  6. Check for missing values and impute the missing values with an
# appropriate value. (mean for continuous and mode for categorical)

# %%
complete.claim_amount[complete.claim_amount.isna()] = complete.claim_amount.mean()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14376\262607298.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complete.claim_amount[complete.claim_amount.isna()] = complete.claim_amount.mean()

# %%
complete.claim_amount.isna().sum()
# Out:
# 0

# %%
complete.total_policy_claims[complete.total_policy_claims.isna()] = float(complete.total_policy_claims.mode())
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14376\3210660765.py:1: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   complete.total_policy_claims[complete.total_policy_claims.isna()] = float(complete.total_policy_claims.mode())
# C:\Users\hp\AppData\Local\Temp\ipykernel_14376\3210660765.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complete.total_policy_claims[complete.total_policy_claims.isna()] = float(complete.total_policy_claims.mode())

# %%
complete.total_policy_claims.isna().sum()
# Out:
# 0

# %% [raw]
# 7. Calculate the age of customers in years. Based on the age, categorize the
#  customers according to the below criteria
#  Children
#  < 18
#  Youth
#  Adult
#  Senior
# 18-30
#  30-60
#  > 60

# %%
complete['age'] = pd.Timestamp.now().year - complete.DateOfBirth.dt.year

# %%
complete.age
# Out:
# 0      -42
# 1       49
# 2      -43
# 3       48
# 4       39
#         ..
# 1080    26
# 1081    32
# 1082    51
# 1083    40
# 1084    31
# Name: age, Length: 1078, dtype: int32

# %%
def category(x):
    if x <= 18:
        return 'Children'
    elif 18 < x <= 30:
        return 'Youth'
    elif 30 < x < 60:
        return 'Adult'
    else:
        return 'Senior'

# %%
complete['Age_group'] = complete['age'].apply(category)

# %%
complete.Age_group
# Out:
# 0       Children
# 1          Adult
# 2       Children
# 3          Adult
# 4          Adult
#           ...
# 1080       Youth
# 1081       Adult
# 1082       Adult
# 1083       Adult
# 1084       Adult
# Name: Age_group, Length: 1078, dtype: object

# %% [raw]
#  8. What is the average amount claimed by the customers from various
# segments?

# %%
complete.groupby('Segment').claim_amount.mean()
# Out:
# Segment
# Gold        12846.400227
# Platinum    12371.654843
# Silver      12267.859374
# Name: claim_amount, dtype: float64

# %% [raw]
#  9. What is the total claim amount based on incident cause for all the claims
#  that have been done at least 20 days prior to 1st of October, 2018.

# %%
cut_off = pd.to_datetime('2018-10-01') - pd.Timedelta(days = 20)

# %%
filtered_claims = complete[complete['claim_date'] <= cut_off]

# %%
total_claim = filtered_claims.groupby(by = ['incident_cause'])[['claim_amount']].sum()

# %%
total_claim
# Out:
#                     claim_amount
# incident_cause
# Crime               7.219386e+05
# Driver error        3.315851e+06
# Natural causes      1.312987e+06
# Other causes        3.723152e+06
# Other driver error  3.277536e+06

# %%
total_claim.plot(kind = 'bar')
# Out:
# <Axes: xlabel='incident_cause'>

# %% [raw]
#  10. How many adults from TX, DE and AK claimed insurance for driver
# related issues and causes?

# %%
p = complete[(complete.age>17) & complete.State.isin(['TX','DE','AK']) & complete.incident_cause.isin(['Driver error','Other  driver error'])]
p
# Out:
#       CUST_ID  gender DateOfBirth State     Contact   Segment  claim_id  \
# 95   39959491  Female  1995-04-07    DE  1397425417    Silver  54642809
# 112  68772500    Male  1989-11-10    TX  5622595432    Silver  21550521
# 171  65899365  Female  1973-07-25    TX  1359718567  Platinum  86096444
# 212  29903212    Male  1989-12-16    DE  2799183268  Platinum   7136079
# 321  84147585    Male  1972-10-18    AK  7435694783      Gold  78221963
# 322    154557  Female  1978-05-23    DE  9628791238  Platinum  69348631
# 378  94643289    Male  1998-04-24    AK  3176121425    Silver  34596802
# 408  77006226  Female  1998-02-13    TX  6412955498  Platinum  21146312
# 475  13687085    Male  1997-11-18    DE  1371467356  Platinum  37688454
# 573   4669941    Male  1982-08-03    AK  7614623458  Platinum     70068
# 580  32464636  Female  1988-08-25    DE  8622471496      Gold  99281527
# 589  62204138  Female  1989-12-15    DE  4719344961  Platinum  93028492
# 655  74787956    Male  1989-06-19    TX  6795145894      Gold  12612736
# 707  18282409  Female  1973-09-29    AK  3262157361      Gold  94983900
# 777  26489135    Male  1994-10-05    DE  6544561493  Platinum  70399158
# 878  92752865    Male  1986-01-30    AK  1432195498    Silver  82144259
# 930  44050095    Male  1977-06-04    DE  3142989257  Platinum  17396013
# 979  66433138    Male  1978-06-27    TX  7526173867      Gold  22577147
#
#      customer_id incident_cause claim_date claim_area police_report  \
# 95      39959491   Driver error 2018-09-06       Auto       Unknown
# 112     68772500   Driver error 2018-08-30       Auto       Unknown
# 171     65899365   Driver error 2018-07-14       Auto            No
# 212     29903212   Driver error 2018-06-17       Auto            No
# 321     84147585   Driver error 2018-04-10       Auto           Yes
# 322       154557   Driver error 2018-04-10       Auto            No
# 378     94643289   Driver error 2018-03-14       Auto            No
# 408     77006226   Driver error 2018-02-15       Auto            No
# 475     13687085   Driver error 2018-01-13       Auto       Unknown
# 573      4669941   Driver error 2017-11-06       Auto       Unknown
# 580     32464636   Driver error 2017-10-31       Auto            No
# 589     62204138   Driver error 2017-10-31       Auto       Unknown
# 655     74787956   Driver error 2017-09-14       Auto       Unknown
# 707     18282409   Driver error 2017-08-11       Auto            No
# 777     26489135   Driver error 2017-07-01       Auto            No
# 878     92752865   Driver error 2017-04-25       Auto            No
# 930     44050095   Driver error 2017-03-22       Auto       Unknown
# 979     66433138   Driver error 2017-02-23       Auto            No
#
#               claim_type  claim_amount  total_policy_claims fraudulent  flag  \
# 95         Material only   2720.000000                  1.0         No     0
# 112        Material only   2320.000000                  1.0         No     0
# 171  Material and injury  34160.000000                  1.0         No     0
# 212        Material only   2668.000000                  2.0        Yes     0
# 321          Injury only  14430.000000                  4.0         No     1
# 322          Injury only  12501.726555                  1.0        Yes     0
# 378  Material and injury  45287.000000                  1.0        Yes     0
# 408        Material only   2930.000000                  1.0         No     0
# 475          Injury only  16760.000000                  1.0         No     0
# 573          Injury only  29900.000000                  1.0        Yes     0
# 580        Material only   2323.000000                  1.0        Yes     0
# 589        Material only   2691.000000                  1.0        Yes     0
# 655        Material only  12501.726555                  1.0         No     0
# 707          Injury only  31020.000000                  2.0         No     0
# 777        Material only   1110.000000                  1.0         No     0
# 878          Injury only  12501.726555                  1.0         No     0
# 930  Material and injury  20458.500000                  1.0        Yes     0
# 979  Material and injury  21447.500000                  2.0        Yes     0
#
#      age Age_group
# 95    30     Youth
# 112   36     Adult
# 171   52     Adult
# 212   36     Adult
# 321   53     Adult
# 322   47     Adult
# 378   27     Youth
# 408   27     Youth
# 475   28     Youth
# 573   43     Adult
# 580   37     Adult
# 589   36     Adult
# 655   36     Adult
# 707   52     Adult
# 777   31     Adult
# 878   39     Adult
# 930   48     Adult
# 979   47     Adult

# %%
p.CUST_ID.count()
# Out:
# 18

# %%
complete.Age_group.value_counts()
# Out:
# Age_group
# Adult       692
# Children    245
# Youth       141
# Name: count, dtype: int64

# %%
complete[(complete.Age_group == 'Adult') & complete.State.isin(['TX','DE','AK']) & complete.incident_cause.isin(['Driver error','Other driver error'])].CUST_ID.count()
# Out:
# 24

# %%
x = complete[(complete.age > 17) & complete.State.isin(['TX','DE','AK'])]

# %%
y = x[(x['incident_cause'].isin(['Driver error','Other driver error']))]

# %%
y
# Out:
#       CUST_ID  gender DateOfBirth State     Contact   Segment  claim_id  \
# 4    77510822  Female  1986-03-18    AK  4369347156    Silver  87329176
# 67   92971195    Male  1975-02-02    DE  8921734657      Gold  92399694
# 80   61810954    Male  1969-05-18    TX  7244936179    Silver  65335959
# 95   39959491  Female  1995-04-07    DE  1397425417    Silver  54642809
# 112  68772500    Male  1989-11-10    TX  5622595432    Silver  21550521
# 167    684748    Male  1977-08-03    AK  6133852863      Gold   7238381
# 171  65899365  Female  1973-07-25    TX  1359718567  Platinum  86096444
# 212  29903212    Male  1989-12-16    DE  2799183268  Platinum   7136079
# 273   2632562  Female  1985-12-14    AK  4985979658  Platinum   4506676
# 321  84147585    Male  1972-10-18    AK  7435694783      Gold  78221963
# 322    154557  Female  1978-05-23    DE  9628791238  Platinum  69348631
# 341  19796899  Female  1975-12-17    TX  7258738239      Gold   9124181
# 378  94643289    Male  1998-04-24    AK  3176121425    Silver  34596802
# 408  77006226  Female  1998-02-13    TX  6412955498  Platinum  21146312
# 475  13687085    Male  1997-11-18    DE  1371467356  Platinum  37688454
# 573   4669941    Male  1982-08-03    AK  7614623458  Platinum     70068
# 580  32464636  Female  1988-08-25    DE  8622471496      Gold  99281527
# 589  62204138  Female  1989-12-15    DE  4719344961  Platinum  93028492
# 655  74787956    Male  1989-06-19    TX  6795145894      Gold  12612736
# 707  18282409  Female  1973-09-29    AK  3262157361      Gold  94983900
# 777  26489135    Male  1994-10-05    DE  6544561493  Platinum  70399158
# 804  82415154  Female  1980-03-08    DE  5789421542  Platinum  46572741
# 872   3159546    Male  1987-10-20    TX  5861299752  Platinum  26716331
# 878  92752865    Male  1986-01-30    AK  1432195498    Silver  82144259
# 930  44050095    Male  1977-06-04    DE  3142989257  Platinum  17396013
# 962  84750181  Female  1993-05-16    AK  4194316251  Platinum  34691767
# 979  66433138    Male  1978-06-27    TX  7526173867      Gold  22577147
# 996  54094880    Male  1984-06-01    DE  5684817418    Silver  34621474
#
#      customer_id      incident_cause claim_date claim_area police_report  \
# 4       77510822  Other driver error 2018-10-30       Auto       Unknown
# 67      92971195  Other driver error 2018-09-26       Home            No
# 80      61810954  Other driver error 2018-09-19       Auto       Unknown
# 95      39959491        Driver error 2018-09-06       Auto       Unknown
# 112     68772500        Driver error 2018-08-30       Auto       Unknown
# 167       684748  Other driver error 2018-07-14       Auto            No
# 171     65899365        Driver error 2018-07-14       Auto            No
# 212     29903212        Driver error 2018-06-17       Auto            No
# 273      2632562  Other driver error 2018-05-14       Home       Unknown
# 321     84147585        Driver error 2018-04-10       Auto           Yes
# 322       154557        Driver error 2018-04-10       Auto            No
# 341     19796899  Other driver error 2018-04-04       Auto           Yes
# 378     94643289        Driver error 2018-03-14       Auto            No
# 408     77006226        Driver error 2018-02-15       Auto            No
# 475     13687085        Driver error 2018-01-13       Auto       Unknown
# 573      4669941        Driver error 2017-11-06       Auto       Unknown
# 580     32464636        Driver error 2017-10-31       Auto            No
# 589     62204138        Driver error 2017-10-31       Auto       Unknown
# 655     74787956        Driver error 2017-09-14       Auto       Unknown
# 707     18282409        Driver error 2017-08-11       Auto            No
# 777     26489135        Driver error 2017-07-01       Auto            No
# 804     82415154  Other driver error 2017-06-11       Auto            No
# 872      3159546  Other driver error 2017-04-25       Auto            No
# 878     92752865        Driver error 2017-04-25       Auto            No
# 930     44050095        Driver error 2017-03-22       Auto       Unknown
# 962     84750181  Other driver error 2017-03-09       Home            No
# 979     66433138        Driver error 2017-02-23       Auto            No
# 996     54094880  Other driver error 2017-02-17       Auto            No
#
#               claim_type  claim_amount  total_policy_claims fraudulent  flag  \
# 4          Material only  12501.726555                  2.0         No     0
# 67         Material only   1140.000000                  1.0         No     0
# 80   Material and injury  36620.000000                  1.0         No     0
# 95         Material only   2720.000000                  1.0         No     0
# 112        Material only   2320.000000                  1.0         No     0
# 167        Material only   2920.000000                  2.0         No     0
# 171  Material and injury  34160.000000                  1.0         No     0
# 212        Material only   2668.000000                  2.0        Yes     0
# 273        Material only   1400.000000                  1.0         No     0
# 321          Injury only  14430.000000                  4.0         No     1
# 322          Injury only  12501.726555                  1.0        Yes     0
# 341  Material and injury  24667.500000                  1.0        Yes     1
# 378  Material and injury  45287.000000                  1.0        Yes     0
# 408        Material only   2930.000000                  1.0         No     0
# 475          Injury only  16760.000000                  1.0         No     0
# 573          Injury only  29900.000000                  1.0        Yes     0
# 580        Material only   2323.000000                  1.0        Yes     0
# 589        Material only   2691.000000                  1.0        Yes     0
# 655        Material only  12501.726555                  1.0         No     0
# 707          Injury only  31020.000000                  2.0         No     0
# 777        Material only   1110.000000                  1.0         No     0
# 804  Material and injury  15240.000000                  1.0         No     0
# 872          Injury only  17590.000000                  4.0         No     0
# 878          Injury only  12501.726555                  1.0         No     0
# 930  Material and injury  20458.500000                  1.0        Yes     0
# 962        Material only   2370.000000                  4.0         No     0
# 979  Material and injury  21447.500000                  2.0        Yes     0
# 996        Material only   1529.500000                  1.0        Yes     0
#
#      age Age_group
# 4     39     Adult
# 67    50     Adult
# 80    56     Adult
# 95    30     Youth
# 112   36     Adult
# 167   48     Adult
# 171   52     Adult
# 212   36     Adult
# 273   40     Adult
# 321   53     Adult
# 322   47     Adult
# 341   50     Adult
# 378   27     Youth
# 408   27     Youth
# 475   28     Youth
# 573   43     Adult
# 580   37     Adult
# 589   36     Adult
# 655   36     Adult
# 707   52     Adult
# 777   31     Adult
# 804   45     Adult
# 872   38     Adult
# 878   39     Adult
# 930   48     Adult
# 962   32     Adult
# 979   47     Adult
# 996   41     Adult

# %%
y.CUST_ID.count()
# Out:
# 28

# %% [raw]
# 11. Draw a pie chart between the aggregated value of claim amount based
# on gender and segment. Represent the claim amount as a percentage on
#  the pie chart.

# %%
x = pd.pivot_table(complete, index = 'Segment',columns = 'gender',values = 'claim_amount')

# %%
x
# Out:
# gender          Female          Male
# Segment
# Gold      12339.441748  13279.849726
# Platinum  12278.352777  12478.841145
# Silver    11641.380032  12825.871029

# %%
plt.figure(figsize = (12,10))
x.plot(kind = 'pie',
       labels = ['Platinum','Silver','Gold'],
       autopct = '%.1f%%',
       subplots = True
      )
# plt.figure(figsize = (10,7))
plt.show()

# %% [raw]
# 12. Among males and females, which gender had claimed the most for any
# type of driver related issues? E.g. This metric can be compared using a
# bar chart

# %%
y = complete[(complete['incident_cause'].isin(['Driver error','Other driver error']))]
y
# Out:
#        CUST_ID  gender DateOfBirth State     Contact   Segment  claim_id  \
# 3     46710738    Male  1977-04-28    MO  9628349361      Gold  74761374
# 4     77510822  Female  1986-03-18    AK  4369347156    Silver  87329176
# 6     40480522  Female  1984-05-30    NV  7392596835      Gold  52377605
# 7     28932340    Male  1996-01-05    LA  6522658231      Gold  25213498
# 9     86491727  Female  1997-01-29    IL  2941873286      Gold  32178193
# ...        ...     ...         ...   ...         ...       ...       ...
# 1074  97514724    Male  1969-06-08    FL  6416847986  Platinum  97666948
# 1078  22756942    Male  1982-10-09    FL  4628233126    Silver  70512964
# 1079  25634799  Female  1974-11-04    KS  7247813692  Platinum  36457152
# 1082  64840478  Female  1974-02-14    NM  9181747461    Silver  23636125
# 1084  61745840  Female  1994-07-24    MA  6126845472  Platinum  90591192
#
#       customer_id      incident_cause claim_date claim_area police_report  \
# 3        46710738        Driver error 2018-10-30       Auto            No
# 4        77510822  Other driver error 2018-10-30       Auto       Unknown
# 6        40480522        Driver error 2018-10-30       Auto       Unknown
# 7        28932340        Driver error 2018-10-30       Auto       Unknown
# 9        86491727        Driver error 2018-10-30       Home       Unknown
# ...           ...                 ...        ...        ...           ...
# 1074     97514724        Driver error 2017-01-01       Home            No
# 1078     22756942        Driver error 2017-01-01       Auto           Yes
# 1079     25634799        Driver error 2017-01-01       Auto            No
# 1082     64840478  Other driver error 2017-01-01       Auto       Unknown
# 1084     61745840  Other driver error 2017-01-01       Home            No
#
#                claim_type  claim_amount  total_policy_claims fraudulent  flag  \
# 3           Material only   1830.000000                  1.0         No     0
# 4           Material only  12501.726555                  2.0         No     0
# 6     Material and injury  26310.000000                  1.0         No     0
# 7           Material only  12501.726555                  1.0         No     0
# 9           Material only   1860.000000                  1.0         No     0
# ...                   ...           ...                  ...        ...   ...
# 1074          Injury only  19120.000000                  1.0         No     0
# 1078          Injury only  20310.000000                  1.0         No     1
# 1079        Material only   2900.000000                  2.0         No     0
# 1082  Material and injury  17290.000000                  1.0         No     0
# 1084  Material and injury  30930.000000                  1.0         No     0
#
#       age Age_group
# 3      48     Adult
# 4      39     Adult
# 6      41     Adult
# 7      29     Youth
# 9      28     Youth
# ...   ...       ...
# 1074   56     Adult
# 1078   43     Adult
# 1079   51     Adult
# 1082   51     Adult
# 1084   31     Adult
#
# [502 rows x 19 columns]

# %%
x = y.groupby(by = ['gender'])['claim_amount'].sum()
x
# Out:
# gender
# Female    3.136718e+06
# Male      3.975412e+06
# Name: claim_amount, dtype: float64

# %%
x.plot(kind = 'bar')
# Out:
# <Axes: xlabel='gender'>

# %% [raw]
#  13. Which age group had the maximum fraudulent policy claims? Visualize
# it on a bar chart.

# %%
complete[complete.fraudulent == 'Yes'].groupby('Age_group').fraudulent.count().plot(kind = 'bar', ylabel = 'Frauds')
plt.show()

# %% [raw]
#  14. Visualize the monthly trend of the total amount that has been claimed
# by the customers. Ensure that on the “month” axis, the month is in a
# chronological order not alphabetical order.

# %%
complete['Month_year'] = complete['claim_date'].dt.strftime("%Y-%B")

# %%
complete.sort_values(by = ['Month_year'],ascending = True)
# Out:
#       CUST_ID  gender DateOfBirth State     Contact   Segment  claim_id  \
# 883  40591588    Male  1984-11-01    CA  6528375837    Silver  80286970
# 913  98199694  Female  1978-04-04    GA  5623191874  Platinum  18265792
# 914  50771198    Male  1994-12-15    ND  3612497392    Silver  73337887
# 915  57043846    Male  1996-12-24    RI  7561974972    Silver  38818122
# 916  55535045    Male  1994-08-11    AR  1645393948      Gold  95437929
# ..        ...     ...         ...   ...         ...       ...       ...
# 78   58934617    Male  1990-04-01    CA  1578963619  Platinum  72555621
# 80   61810954    Male  1969-05-18    TX  7244936179    Silver  65335959
# 81   90646435  Female  1978-12-07    IL  3569758315      Gold  84632427
# 83   91135917    Male  1986-08-15    NV  6971292549  Platinum  81102722
# 74   21240703    Male  2063-07-22    MD  4735612675    Silver  53780662
#
#      customer_id      incident_cause claim_date claim_area police_report  \
# 883     40591588        Driver error 2017-04-25       Auto       Unknown
# 913     98199694        Driver error 2017-04-05       Auto            No
# 914     50771198        Other causes 2017-04-05       Auto           Yes
# 915     57043846        Other causes 2017-04-05       Auto           Yes
# 916     55535045        Driver error 2017-04-05       Auto            No
# ..           ...                 ...        ...        ...           ...
# 78      58934617        Other causes 2018-09-19       Auto           Yes
# 80      61810954  Other driver error 2018-09-19       Auto       Unknown
# 81      90646435        Other causes 2018-09-19       Auto       Unknown
# 83      91135917  Other driver error 2018-09-12       Auto            No
# 74      21240703  Other driver error 2018-09-19       Auto       Unknown
#
#               claim_type  claim_amount  total_policy_claims fraudulent  flag  \
# 883  Material and injury       39928.0                  1.0        Yes     0
# 913  Material and injury       22540.0                  1.0         No     0
# 914        Material only        1020.0                  1.0         No     1
# 915          Injury only       34490.0                  1.0         No     1
# 916        Material only        1110.0                  1.0         No     0
# ..                   ...           ...                  ...        ...   ...
# 78           Injury only       27002.0                  3.0        Yes     1
# 80   Material and injury       36620.0                  1.0         No     0
# 81           Injury only       25350.0                  1.0         No     0
# 83         Material only        2710.0                  1.0         No     0
# 74         Material only        1050.0                  1.0         No     0
#
#      age Age_group      Month_year
# 883   41     Adult      2017-April
# 913   47     Adult      2017-April
# 914   31     Adult      2017-April
# 915   29     Youth      2017-April
# 916   31     Adult      2017-April
# ..   ...       ...             ...
# 78    35     Adult  2018-September
# 80    56     Adult  2018-September
# 81    47     Adult  2018-September
# 83    39     Adult  2018-September
# 74   -38  Children  2018-September
#
# [1078 rows x 20 columns]

# %%
x = complete.groupby(by = ['Month_year'])[['claim_amount']].sum().reset_index()
x.sort_values('Month_year',ascending = True)
# Out:
#         Month_year   claim_amount
# 0       2017-April  747975.726555
# 1      2017-August  431616.453110
# 2    2017-December  694252.726555
# 3    2017-February  631456.453110
# 4     2017-January  608016.179664
# 5        2017-July  790868.906219
# 6        2017-June  560143.726555
# 7       2017-March  615576.453110
# 8         2017-May  546741.679664
# 9    2017-November  601187.453110
# 10    2017-October  608989.179664
# 11  2017-September  459469.085884
# 12      2018-April  544538.226555
# 13     2018-August  479680.726555
# 14   2018-February  533085.953110
# 15    2018-January  719154.406219
# 16       2018-July  588447.132774
# 17       2018-June  718886.632774
# 18      2018-March  704673.679664
# 19        2018-May  567719.632774
# 20    2018-October  800649.632774
# 21  2018-September  523731.179664

# %%
x
# Out:
#         Month_year   claim_amount
# 0       2017-April  747975.726555
# 1      2017-August  431616.453110
# 2    2017-December  694252.726555
# 3    2017-February  631456.453110
# 4     2017-January  608016.179664
# 5        2017-July  790868.906219
# 6        2017-June  560143.726555
# 7       2017-March  615576.453110
# 8         2017-May  546741.679664
# 9    2017-November  601187.453110
# 10    2017-October  608989.179664
# 11  2017-September  459469.085884
# 12      2018-April  544538.226555
# 13     2018-August  479680.726555
# 14   2018-February  533085.953110
# 15    2018-January  719154.406219
# 16       2018-July  588447.132774
# 17       2018-June  718886.632774
# 18      2018-March  704673.679664
# 19        2018-May  567719.632774
# 20    2018-October  800649.632774
# 21  2018-September  523731.179664

# %%
plt.figure(figsize = (22,6))
plt.plot( x['Month_year'].astype(str),
         x['claim_amount'],
        marker = 'o')

# %%
x.plot(kind = 'barh',
      x = 'Month_year',
      y = 'claim_amount',figsize = (10,4))
plt.show()

# %% [raw]
# 15. What is the average claim amount for gender and age categories and
# suitably represent the above using a facetted bar chart, one facet that
# represents fraudulent claims and the other for non-fraudulent claims.

# %%
sns.catplot(data = complete,
            x = 'gender',
            y='claim_amount',
            hue='Age_group',
            col = 'fraudulent',
            kind = 'bar')
plt.show()

# %% [raw]
#  Based on the conclusions from exploratory analysis as well as suitable
# statistical tests, answer the below questions. Please include a detailed
# write-up on the parameters taken into consideration, the Hypothesis
# testing steps, conclusion from the p-values and the business implications of
# the statements.

# %% [raw]
# 16. Is there any similarity in the amount claimed by males and females?

# %%
only_female = complete[(complete.gender == 'Female')]

# %%
only_female
# Out:
#        CUST_ID  gender DateOfBirth State     Contact   Segment  claim_id  \
# 1     38011078  Female  1976-05-20    NE  2711231475      Gold  98795403
# 4     77510822  Female  1986-03-18    AK  4369347156    Silver  87329176
# 5     17682060  Female  1974-11-21    NV  1861953465      Gold  49735712
# 6     40480522  Female  1984-05-30    NV  7392596835      Gold  52377605
# 9     86491727  Female  1997-01-29    IL  2941873286      Gold  32178193
# ...        ...     ...         ...   ...         ...       ...       ...
# 1079  25634799  Female  1974-11-04    KS  7247813692  Platinum  36457152
# 1080  77219712  Female  1999-08-05    NH  6495928793  Platinum  61374372
# 1081  42664554  Female  1993-08-13    TN  3969732531      Gold  42280334
# 1082  64840478  Female  1974-02-14    NM  9181747461    Silver  23636125
# 1084  61745840  Female  1994-07-24    MA  6126845472  Platinum  90591192
#
#       customer_id      incident_cause claim_date claim_area police_report  \
# 1        38011078               Crime 2018-10-30       Auto       Unknown
# 4        77510822  Other driver error 2018-10-30       Auto       Unknown
# 5        17682060               Crime 2018-10-30       Home       Unknown
# 6        40480522        Driver error 2018-10-30       Auto       Unknown
# 9        86491727        Driver error 2018-10-30       Home       Unknown
# ...           ...                 ...        ...        ...           ...
# 1079     25634799        Driver error 2017-01-01       Auto            No
# 1080     77219712        Other causes 2017-01-01       Auto            No
# 1081     42664554        Other causes 2017-01-01       Auto            No
# 1082     64840478  Other driver error 2017-01-01       Auto       Unknown
# 1084     61745840  Other driver error 2017-01-01       Home            No
#
#                claim_type  claim_amount  total_policy_claims fraudulent  flag  \
# 1           Material only   1940.000000                  1.0         No     0
# 4           Material only  12501.726555                  2.0         No     0
# 5     Material and injury  17020.000000                  1.0         No     0
# 6     Material and injury  26310.000000                  1.0         No     0
# 9           Material only   1860.000000                  1.0         No     0
# ...                   ...           ...                  ...        ...   ...
# 1079        Material only   2900.000000                  2.0         No     0
# 1080  Material and injury  20200.000000                  1.0         No     0
# 1081          Injury only  27670.000000                  1.0         No     0
# 1082  Material and injury  17290.000000                  1.0         No     0
# 1084  Material and injury  30930.000000                  1.0         No     0
#
#       age Age_group    Month_year
# 1      49     Adult  2018-October
# 4      39     Adult  2018-October
# 5      51     Adult  2018-October
# 6      41     Adult  2018-October
# 9      28     Youth  2018-October
# ...   ...       ...           ...
# 1079   51     Adult  2017-January
# 1080   26     Youth  2017-January
# 1081   32     Adult  2017-January
# 1082   51     Adult  2017-January
# 1084   31     Adult  2017-January
#
# [527 rows x 20 columns]

# %%
only_male = complete[(complete.gender == 'Male')]

# %%
only_male
# Out:
#        CUST_ID gender DateOfBirth State     Contact   Segment  claim_id  \
# 0     93915431   Male  2067-09-08    ME  1347851687      Gold  99775483
# 2     58451506   Male  2068-04-22    FL  6735747823      Gold  43042986
# 3     46710738   Male  1977-04-28    MO  9628349361      Gold  74761374
# 7     28932340   Male  1996-01-05    LA  6522658231      Gold  25213498
# 8     65208809   Male  2064-04-22    VA  2861286132  Platinum  91386759
# ...        ...    ...         ...   ...         ...       ...       ...
# 1074  97514724   Male  1969-06-08    FL  6416847986  Platinum  97666948
# 1075  65176092   Male  1975-11-23    NC  6513792486    Silver   9476314
# 1076  39587790   Male  2065-01-10    LA  6151543516      Gold  39131766
# 1078  22756942   Male  1982-10-09    FL  4628233126    Silver  70512964
# 1083  74155265   Male  1985-11-16    TX  3927394873      Gold  25647821
#
#       customer_id  incident_cause claim_date claim_area police_report  \
# 0        93915431    Other causes 2018-10-30       Auto            No
# 2        58451506  Natural causes 2018-10-30       Auto            No
# 3        46710738    Driver error 2018-10-30       Auto            No
# 7        28932340    Driver error 2018-10-30       Auto       Unknown
# 8        65208809  Natural causes 2018-10-30       Auto            No
# ...           ...             ...        ...        ...           ...
# 1074     97514724    Driver error 2017-01-01       Home            No
# 1075     65176092    Other causes 2017-01-01       Auto            No
# 1076     39587790    Other causes 2017-01-01       Auto            No
# 1078     22756942    Driver error 2017-01-01       Auto           Yes
# 1083     74155265  Natural causes 2017-01-01       Auto            No
#
#                claim_type  claim_amount  total_policy_claims fraudulent  flag  \
# 0     Material and injury  42124.500000                  1.0        Yes     0
# 2           Material only   2420.000000                  1.0         No     0
# 3           Material only   1830.000000                  1.0         No     0
# 7           Material only  12501.726555                  1.0         No     0
# 8           Material only   2290.000000                  1.0         No     0
# ...                   ...           ...                  ...        ...   ...
# 1074          Injury only  19120.000000                  1.0         No     0
# 1075  Material and injury  37290.000000                  3.0         No     0
# 1076        Material only   2967.000000                  1.0        Yes     0
# 1078          Injury only  20310.000000                  1.0         No     1
# 1083        Material only   2080.000000                  1.0         No     0
#
#       age Age_group    Month_year
# 0     -42  Children  2018-October
# 2     -43  Children  2018-October
# 3      48     Adult  2018-October
# 7      29     Youth  2018-October
# 8     -39  Children  2018-October
# ...   ...       ...           ...
# 1074   56     Adult  2017-January
# 1075   50     Adult  2017-January
# 1076  -40  Children  2017-January
# 1078   43     Adult  2017-January
# 1083   40     Adult  2017-January
#
# [551 rows x 20 columns]

# %%
female_claim = only_female.claim_amount
female_claim
# Out:
# 1        1940.000000
# 4       12501.726555
# 5       17020.000000
# 6       26310.000000
# 9        1860.000000
#             ...
# 1079     2900.000000
# 1080    20200.000000
# 1081    27670.000000
# 1082    17290.000000
# 1084    30930.000000
# Name: claim_amount, Length: 527, dtype: float64

# %%
male_claim = only_male.claim_amount
male_claim
# Out:
# 0       42124.500000
# 2        2420.000000
# 3        1830.000000
# 7       12501.726555
# 8        2290.000000
#             ...
# 1074    19120.000000
# 1075    37290.000000
# 1076     2967.000000
# 1078    20310.000000
# 1083     2080.000000
# Name: claim_amount, Length: 551, dtype: float64

# %%
# define Hypothesis

# h0 = Male and Female claim amount similar
# ha = male and female claim amount different

# setup confidence interval 

# C.I = 95%
# Alpha = 0.05

# setup test statistics
# we use t_test independent test

# %%
stats.ttest_ind(male_claim,female_claim)
# Out:
# TtestResult(statistic=0.9625093446632118, pvalue=0.33601006135365463, df=1076.0)

# %%
# here p-value = 0.336
# setup Alpha = 0.05

# p-value > Alpha
# i.e 0.336 > 0.005

# we failed to accept Alternative hypothesis
# We accept Null hypothesis

# %% [raw]
#  17. Is there any relationship between age category and segment?

# %%
# It is a relationship among categorical variables
# so we use Chi-square test

# %%
# define Hypothesis

# H0 = No relationship
# Ha = There is a relationship

# columns = age category & segment

# set up confidence interval
#   ---- C.I = 95%
#   ----Alpha = 0.05

# test statistic
#   --- Chi-square test

# %%
# we need cross tab, which means cross table for Age group and semgemnt

# %%
table  = pd.crosstab(complete.Age_group,complete.Segment)

# %%
table
# Out:
# Segment    Gold  Platinum  Silver
# Age_group
# Adult       242       234     216
# Children     81        83      81
# Youth        48        44      49

# %%
# perform test statistic
stats.chi2_contingency(table)
# Out:
# Chi2ContingencyResult(statistic=0.9995864462169217, pvalue=0.9098586913465189, dof=4, expected_freq=array([[238.15584416, 231.73654917, 222.10760668],
#        [ 84.31818182,  82.04545455,  78.63636364],
#        [ 48.52597403,  47.21799629,  45.25602968]]))

# %%
# p-value = 0.90
# Alpha   = 0.05

# p-value > Alpha 
# 0.90 > 0.05

# so we accept null hypothesis
# we fail to accept to alternative hypothesis(reject hypothesis)

# Result  :  There is a no relationship between age category and segment

# %% [raw]
#  18. The current year has shown a significant rise in claim amounts as
# compared to 2016-17 fiscal average which was $10,000.

# %%
# we dont now how much rise in claim amount
# so lets assume it is 50%

# claim is there is a significant rise in claim amount
# u > 50%

# %%
# define Hypothesis

# h0: u<=50  (u= average amount claim)
# ha: u>50

# set up confidence intervals
# C.I = 95%
# Alpha = 0.05

# setup test statistics
# we use t_test one sample 
# because there is no standard deviation

# parameters = claim_amount
# year = 2018

# %%
stats.ttest_1samp(complete.claim_amount[complete.claim_date.dt.year==2018],10000)
# Out:
# TtestResult(statistic=4.477343563243787, pvalue=9.43584422198333e-06, df=484)

# %%
# p-value = 9.43584422198333e-06
# Alpha = 0.05

# p-value < Alpha
# 9.43584422198333e-06 < 0.05

# We fail to accept null hypothesis
# we accept the alternative hypothesis

# The current year has a significant rise in claim amounts compared to 2016-17 fiscal average $10000.

# %% [raw]
#  20. Is there any relationship between total number of policy claims and the claimed amount?

# %%
# here we are finding relationship between two numerical variables

# %%
# paremeters 
# total_no_of_policy_claims
# total_claimed amount

# %%
# we use correlation
# correlation tells the relationship between the two numerical variable(columns)

# %%
complete.total_policy_claims.corr(other = complete.claim_amount)
# Out:
# -0.022401566777628813

# %%
# there a strong negative correlation between total no of policy claims & total Claim amounts
# There is Storng negative correlation

# %% [raw]
#  19. Is there any difference between age groups and insurance claims?

# %%
# In Age group we have threee categories
# Adult
# Children
# Youth

# %%
complete.Age_group.value_counts()
# Out:
# Age_group
# Adult       692
# Children    245
# Youth       141
# Name: count, dtype: int64

# %%
# we are find out is there any significance between these 3 groups with claim amount

# %%
# define Hypothesis

# h0 = there is no difference between age groups and claim amount
# ha = thee is a difference between age groups and claim amount

# set up confidence interval
# C.I = 95%
# Alpha = 0.05

# Setup test statistic
# we use one sampler anova test
# which is ftest

# %%
# we want three groups claim amount

x1 = complete.claim_amount[complete.Age_group == 'Adult']
x2 = complete.claim_amount[complete.Age_group == 'Youth']
x3 = complete.claim_amount[complete.Age_group == 'Children']

# %%
x1.mean()
# Out:
# 12897.192546034501

# %%
x1
# Out:
# 1        1940.000000
# 3        1830.000000
# 4       12501.726555
# 5       17020.000000
# 6       26310.000000
#             ...
# 1079     2900.000000
# 1081    27670.000000
# 1082    17290.000000
# 1083     2080.000000
# 1084    30930.000000
# Name: claim_amount, Length: 692, dtype: float64

# %%
x2.mean()
# Out:
# 12021.810393956579

# %%
x2
# Out:
# 7       12501.726555
# 9        1860.000000
# 14       2310.000000
# 15      12501.726555
# 29       1790.000000
#             ...
# 1040     2320.000000
# 1050     2550.000000
# 1057     2910.000000
# 1072     1276.500000
# 1080    20200.000000
# Name: claim_amount, Length: 141, dtype: float64

# %%
x3.mean()
# Out:
# 11660.933545540627

# %%
x3
# Out:
# 0       42124.5
# 2        2420.0
# 8        2290.0
# 12      25160.0
# 21       2553.0
#          ...
# 1064     1770.0
# 1066    21590.0
# 1067    36670.0
# 1069     1552.5
# 1076     2967.0
# Name: claim_amount, Length: 245, dtype: float64

# %%
stats.f_oneway(x1,x2,x3)
# Out:
# F_onewayResult(statistic=0.8787674533332114, pvalue=0.41559257744378064)

# %%
0.41559257744378064 >0.05
# Out:
# True

# %%
# p-value = 0.41559257744378064
# Alpha = 0.05
#
# Out:
# Age_group
# Adult       692
# Children    245
# Youth       141
# Name: count, dtype: int64

# %%
0.41559257744378064 > 0.05
# Out:
# True
